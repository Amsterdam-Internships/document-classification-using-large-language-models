# %%
# !bash /home/azureuser/cloudfiles/code/blobfuse/blobfuse_raadsinformatie.sh

# %%
import sys
sys.path.append("..")

# Select where to run notebook: "azure" or "local"
my_run = "azure"

import my_secrets as sc
import settings as st

if my_run == "azure":
    import config_azure as cf
elif my_run == "local":
    import config as cf


import os
if my_run == "azure":
    if not os.path.exists(cf.HUGGING_CACHE):
        os.mkdir(cf.HUGGING_CACHE)
    os.environ["TRANSFORMERS_CACHE"] = cf.HUGGING_CACHE

import pandas as pd
# setup environment GEITje-7B Finetuning
# - pip install torch
# - pip install datasets
# - pip install transformers
# - pip install trl
# - pip install accelerate (restart after)
# - switch device_map='auto' to avaoid memory error

# - pip install sentencepiece
# - pip install jupyter
# - pip install protobuf

# %% [markdown]
# ### Notebook Overview
# Goal: analyse the baselines, understand why they work so well

# %%
predictions = pd.read_pickle(f"{cf.output_path}/predictionsFinal/baselines/LogisticRegressionpredictions.pkl")
overview = pd.read_pickle(f"{cf.output_path}/predictionsFinal/baselines/overview.pkl")

# %%
from transformers import AutoTokenizer
from collections import Counter
from sklearn.metrics import classification_report
import sys
sys.path.append('../scripts/') 
import prompt_template as pt
import warnings
warnings.simplefilter('ignore')

def percentage_mistakes(count):
    return f"{round(count/1100*100,1)}%"

def mistakes(df, detailed=False):
    print('MISTAKES. INCLUDES PREDICTIONS ERRORS.')

    # select all response where the prediction was not correct
    mistakes = df.loc[df['label'] != df['prediction']]

    # groupby run_id so we get the amount of mistakes per run
    mistakes_per_run = mistakes.groupby('run_id').size().reset_index(name='count')
    mistakes_per_run['percentage of total predictions'] = mistakes_per_run['count'].apply(percentage_mistakes)
    print("Total amount of mistakes per run:")
    display(mistakes_per_run)

    # for each run get the amount of mistakes per class
    df_count_class = pd.DataFrame(columns=pt.get_class_list())
    for run_id in set(mistakes['run_id']):
        # select mistakes of current runid
        subdf = mistakes.loc[mistakes['run_id']==run_id]
        # count mistakes per class
        class_count = dict(Counter(subdf['label']))

        # if a class is not included in mistakes, set counter to 0
        for category in pt.get_class_list():
            if category not in class_count.keys():
                class_count[category] = 0

        # add count of class to df
        df_count_class.loc[len(df_count_class)] = class_count

    # reset index to runids
    df_count_class.index = list(set(mistakes['run_id']))
    print("Amount of mistakes per class for each run:")
    display(df_count_class)

    # For each run get for each class the highest mistakes
    df_highest_class = pd.DataFrame(columns=pt.get_class_list())
    for run_id in set(mistakes['run_id']):
        # select mistakes of current runid
        subdf = mistakes.loc[mistakes['run_id']==run_id]
        # count mistakes of runid
        count_mistakes_per_class = dict(Counter(subdf['label']))

        class_count = subdf.groupby('label')['prediction'].value_counts().reset_index(name='count')
        highest_per_class = dict()
        for label in set(class_count['label']):
            # for each class select the class for which it made the most mistakes
            highest_count_row = class_count.iloc[class_count[class_count['label'] == label]['count'].idxmax()]
            highest_per_class[label] = f"{highest_count_row['prediction']} ({highest_count_row['count']} out of {count_mistakes_per_class[label]})"

        # add to df
        df_highest_class.loc[len(df_highest_class)] = highest_per_class
    # reset index to run_id
    df_highest_class.index = list(set(mistakes['run_id']))
    print("Highest mistakes per class for each run:")
    display(df_highest_class.transpose())


def predictions_per_class(df):
    df_predictions_per_class = pd.DataFrame(columns=pt.get_class_list())
    for run_id in set(df['run_id']):
        subdf = df.loc[df['run_id']==run_id]
        count_predictions = dict(Counter(subdf['prediction']))
        df_predictions_per_class.loc[len(df_predictions_per_class)] = count_predictions

    df_predictions_per_class.index = list(set(df['run_id']))
    display(df_predictions_per_class.transpose())
# Out:
# /anaconda/envs/2AmsterdamLLM/lib/python3.9/site-packages/transformers/utils/hub.py:124: FutureWarning: Using `TRANSFORMERS_CACHE` is deprecated and will be removed in v5 of Transformers. Use `HF_HOME` instead.
#   warnings.warn(

# %%
display(overview.loc[overview['run_id'].isin(predictions['run_id'])])
# Out:
#                 model                             date  \
# 0  LogisticRegression 2024-05-15 16:06:08.417730+02:00
# 0  LogisticRegression 2024-05-15 16:06:24.172787+02:00
# 0  LogisticRegression 2024-05-15 16:06:52.366648+02:00
# 0  LogisticRegression 2024-05-15 16:07:30.577905+02:00
#
#                                 run_id train_set test_set  train_set_support  \
# 0          LogisticRegression_fulltext     train     test               9900
# 0    LogisticRegression_first100_last0     train     test               9900
# 0    LogisticRegression_first200_last0     train     test               9900
# 0  LogisticRegression_first100_last100     train     test               9900
#
#    test_set_support       split_col                              text_col  \
# 0              1100  balanced_split  TruncationLlamaTokensFront100Back100
# 0              1100  balanced_split    TruncationLlamaTokensFront100Back0
# 0              1100  balanced_split    TruncationLlamaTokensFront200Back0
# 0              1100  balanced_split  TruncationLlamaTokensFront100Back100
#
#      runtime  accuracy  macro_avg_precision  macro_avg_recall  macro_avg_f1  \
# 0  52.680659  0.874545             0.903397          0.874545      0.864052
# 0  25.670804  0.854545             0.903185          0.854545      0.835388
# 0  38.030517  0.862727             0.907136          0.862727      0.846879
# 0  47.476278  0.852727             0.905185          0.852727      0.833257
#
#                                classification_report
# 0                       precision    recall  f1-s...
# 0                       precision    recall  f1-s...
# 0                       precision    recall  f1-s...
# 0                       precision    recall  f1-s...

# %%
mistakes(predictions)
predictions_per_class(predictions)
# Out:
# MISTAKES. INCLUDES PREDICTIONS ERRORS.
# Total amount of mistakes per run:
#                                 run_id  count percentage of total predictions
# 0    LogisticRegression_first100_last0    160                           14.5%
# 1  LogisticRegression_first100_last100    162                           14.7%
# 2    LogisticRegression_first200_last0    151                           13.7%
# 3          LogisticRegression_fulltext    138                           12.5%
# Amount of mistakes per class for each run:
#                                      Voordracht  Besluit  Schriftelijke Vraag  \
# LogisticRegression_first200_last0             1        8                    8
# LogisticRegression_first100_last0             2        8                    8
# LogisticRegression_fulltext                   1        6                    7
# LogisticRegression_first100_last100           2        8                    9
#
#                                      Brief  Raadsadres  Onderzoeksrapport  \
# LogisticRegression_first200_last0        5           3                  6
# LogisticRegression_first100_last0        5           5                  4
# LogisticRegression_fulltext              3           1                  8
# LogisticRegression_first100_last100      7           3                  3
#
#                                      Raadsnotulen  Agenda  Motie  Actualiteit  \
# LogisticRegression_first200_last0               3       1      6           24
# LogisticRegression_first100_last0               2       3      6           27
# LogisticRegression_fulltext                     4       1      6           30
# LogisticRegression_first100_last100             6       1      6           25
#
#                                      Factsheet
# LogisticRegression_first200_last0           86
# LogisticRegression_first100_last0           90
# LogisticRegression_fulltext                 71
# LogisticRegression_first100_last100         92
# Highest mistakes per class for each run:
#                     LogisticRegression_first200_last0  \
# Voordracht                       Besluit (1 out of 1)
# Besluit                       Raadsadres (6 out of 8)
# Schriftelijke Vraag           Raadsadres (4 out of 8)
# Brief                              Motie (2 out of 5)
# Raadsadres             Onderzoeksrapport (3 out of 3)
# Onderzoeksrapport             Raadsadres (5 out of 6)
# Raadsnotulen                      Agenda (3 out of 3)
# Agenda                 Onderzoeksrapport (1 out of 1)
# Motie                              Brief (3 out of 6)
# Actualiteit                 Raadsadres (11 out of 24)
# Factsheet            Onderzoeksrapport (79 out of 86)
#
#                     LogisticRegression_first100_last0  \
# Voordracht                       Besluit (1 out of 2)
# Besluit                       Raadsadres (8 out of 8)
# Schriftelijke Vraag           Raadsadres (4 out of 8)
# Brief                              Motie (2 out of 5)
# Raadsadres             Onderzoeksrapport (4 out of 5)
# Onderzoeksrapport             Raadsadres (4 out of 4)
# Raadsnotulen                      Agenda (2 out of 2)
# Agenda                        Voordracht (2 out of 3)
# Motie                              Brief (3 out of 6)
# Actualiteit                 Raadsadres (15 out of 27)
# Factsheet            Onderzoeksrapport (81 out of 90)
#
#                           LogisticRegression_fulltext  \
# Voordracht                       Besluit (1 out of 1)
# Besluit                       Raadsadres (4 out of 6)
# Schriftelijke Vraag           Raadsadres (5 out of 7)
# Brief                             Agenda (1 out of 3)
# Raadsadres           Schriftelijke Vraag (1 out of 1)
# Onderzoeksrapport             Raadsadres (4 out of 8)
# Raadsnotulen                 Actualiteit (2 out of 4)
# Agenda               Schriftelijke Vraag (1 out of 1)
# Motie                              Brief (3 out of 6)
# Actualiteit                 Raadsadres (11 out of 30)
# Factsheet            Onderzoeksrapport (52 out of 71)
#
#                     LogisticRegression_first100_last100
# Voordracht                         Besluit (1 out of 2)
# Besluit                         Raadsadres (5 out of 8)
# Schriftelijke Vraag             Raadsadres (4 out of 9)
# Brief                    Onderzoeksrapport (3 out of 7)
# Raadsadres               Onderzoeksrapport (2 out of 3)
# Onderzoeksrapport               Raadsadres (3 out of 3)
# Raadsnotulen                        Agenda (3 out of 6)
# Agenda                   Onderzoeksrapport (1 out of 1)
# Motie                           Raadsadres (4 out of 6)
# Actualiteit                    Raadsadres (9 out of 25)
# Factsheet              Onderzoeksrapport (90 out of 92)
#                      LogisticRegression_first200_last0  \
# Voordracht                                         102
# Besluit                                             95
# Schriftelijke Vraag                                 92
# Brief                                               99
# Raadsadres                                         134
# Onderzoeksrapport                                  183
# Raadsnotulen                                        97
# Agenda                                             105
# Motie                                               99
# Actualiteit                                         80
# Factsheet                                           14
#
#                      LogisticRegression_first100_last0  \
# Voordracht                                         103
# Besluit                                             96
# Schriftelijke Vraag                                 92
# Brief                                               99
# Raadsadres                                         140
# Onderzoeksrapport                                  185
# Raadsnotulen                                        98
# Agenda                                             102
# Motie                                              101
# Actualiteit                                         74
# Factsheet                                           10
#
#                      LogisticRegression_fulltext  \
# Voordracht                                   103
# Besluit                                       96
# Schriftelijke Vraag                           98
# Brief                                        104
# Raadsadres                                   143
# Onderzoeksrapport                            149
# Raadsnotulen                                  96
# Agenda                                       105
# Motie                                        104
# Actualiteit                                   73
# Factsheet                                     29
#
#                      LogisticRegression_first100_last100
# Voordracht                                           102
# Besluit                                               96
# Schriftelijke Vraag                                   91
# Brief                                                 96
# Raadsadres                                           129
# Onderzoeksrapport                                    200
# Raadsnotulen                                          94
# Agenda                                               105
# Motie                                                100
# Actualiteit                                           79
# Factsheet                                              8
# Bad pipe message: %s [b'\xa2\xdb\x88f\x96{:\xd3\xcdU\xc1Jx\xafy\x97\x8c\xb1 \x82o\xbbv\xdbx#7\xb6x\xae\xc4\xe9\x93f>{\xd9K~\xec.w\x00\xa1\x98\xb7\x99\xa5\xde\xee\\\x00\x08\x13\x02\x13\x03\x13\x01\x00\xff\x01\x00\x00\x8f\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x00\x1e\x00\x1c\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01\x06\x01\x00+\x00\x03\x02\x03\x04\x00-\x00\x02\x01\x01\x003\x00&\x00$\x00\x1d\x00 l\x88\x7fG\x1a<\xd7u2\rY\xa1\\\x85\x91\xa4\xe7^\x9b\xf5\x86\xb1\xba\x06p,^{\x88\xc0\x1f\x1f']
# Bad pipe message: %s [b'9I\x01\x9d\x9e\x80\xf4[\xd3\xe7\xfe\xc3\xecu~)\xac\xe0\x00\x00|\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0']
# Bad pipe message: %s [b"\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0#\xc0'\x00g\x00@\xc0\n\xc0\x14\x009\x008\xc0\t\xc0\x13\x003\x002\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00<\x005\x00/\x00\x9a\x00\x99\xc0\x07\xc0\x11\x00\x96\x00\x05\x00\xff\x01\x00\x00j\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x0c\x00\n\x00\x1d\x00\x17\x00\x1e\x00\x19\x00\x18\x00#\x00\x00\x00\x16\x00\x00\x00\x17\x00\x00\x00\r\x000\x00.\x04\x03\x05\x03\x06\x03\x08\x07\x08\x08\x08\t\x08\n\x08\x0b\x08\x04\x08\x05\x08\x06\x04\x01\x05\x01"]
# Bad pipe message: %s [b'\x03\x03\x02\x03\x03', b'']
# Bad pipe message: %s [b'', b'\x02']
# Bad pipe message: %s [b'vF\x05\xa7\xfc\xc3?2b\xff\xcd\x1e\xe9\xd8R\xfe"p\x00\x00\xa6\xc0,\xc00\x00\xa3\x00\x9f\xcc\xa9\xcc\xa8\xcc\xaa\xc0\xaf\xc0\xad\xc0\xa3\xc0\x9f\xc0]\xc0a\xc0W\xc0S\xc0+\xc0/\x00\xa2\x00\x9e\xc0\xae\xc0\xac\xc0\xa2\xc0\x9e\xc0\\\xc0`\xc0V\xc0R\xc0$\xc0(\x00k\x00j\xc0s\xc0w\x00\xc4\x00\xc3\xc0#\xc0\'\x00g\x00@\xc0r\xc0v\x00\xbe\x00\xbd\xc0\n\xc0\x14\x009\x008\x00\x88\x00\x87\xc0\t\xc0\x13\x003\x002\x00\x9a\x00\x99\x00E\x00D\xc0\x07\xc0\x11\xc0\x08\xc0\x12\x00\x16\x00\x13\x00\x9d\xc0\xa1\xc0\x9d\xc0Q\x00\x9c\xc0\xa0\xc0\x9c\xc0P\x00=\x00\xc0\x00<\x00\xba\x005\x00\x84\x00/\x00\x96\x00A\x00\x05\x00\n\x00\xff\x01\x00\x00j\x00\x00\x00']
# Bad pipe message: %s [b'\x05\x02\x06']
# Bad pipe message: %s [b'\x0c\x00\x00\t127.0.0.1']
# Bad pipe message: %s [b'\x96\xda\xb7j\x99\x11\x07\x10\x86\xf6\x0b\xd5\xbcB3\xe4P\xd6\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88\x00\x87\x00\x86\x00\x85\xc0\x19\x00:\x00\x89\xc0\x0f\xc0\x05\x005\x00\x84\xc0\x13\xc0\t\x003\x002\x001\x000\x00\x9a\x00\x99\x00\x98\x00\x97\x00E\x00D\x00C\x00B\xc0\x18\x004\x00\x9b\x00F\xc0\x0e\xc0\x04\x00/\x00\x96\x00A\x00\x07\xc0\x11\xc0\x07\xc0\x16\x00\x18\xc0\x0c\xc0\x02\x00\x05\x00\x04\xc0\x12\xc0\x08\x00\x16\x00\x13\x00\x10\x00\r\xc0\x17\x00\x1b\xc0\r\xc0\x03\x00\n\x00\x15\x00\x12\x00\x0f\x00\x0c\x00\x1a\x00\t\x00\x14\x00\x11\x00\x19\x00\x08\x00\x06\x00\x17\x00\x03\xc0\x10\xc0\x06\xc0\x15\xc0\x0b\xc0\x01\x00\x02\x00\x01\x00\xff\x02\x01\x00\x00C\x00\x00\x00\x0e\x00\x0c\x00\x00\t127.0.0.1\x00\x0b\x00\x04\x03\x00\x01\x02\x00\n\x00\x1c\x00\x1a\x00\x17\x00\x19\x00\x1c\x00\x1b\x00\x18\x00\x1a\x00\x16\x00\x0e\x00\r\x00\x0b\x00\x0c\x00\t']
# Bad pipe message: %s [b'\xd4!bP\xc3\xda\x1b\x9b\xf1\xc9H-\x1f5']
# Bad pipe message: %s [b'\x9f\xec\xb3\xd1L<\x11C}\xd5\xec\xc2\x88\x02\xe4\xd5\xb1\xab\x00\x00\xa2\xc0\x14\xc0\n\x009\x008\x007\x006\x00\x88']

# %% [markdown]
# Mistakes: most trouble with Factsheet, they get mistaken as onderzoeksrapport. It can be seen that factsheet gets predicted very little, while onderzoeksrapporten a lot more. Factsheets do tend to contain a lot of image gibberish, the same as onderzoeksrapport.
