# %%
# !bash /home/azureuser/cloudfiles/code/blobfuse/blobfuse_raadsinformatie.sh

# %%
import sys
sys.path.append("..")

# Select where to run notebook: "azure" or "local"
my_run = "azure"

# import my_secrets as sc
# import settings as st

if my_run == "azure":
    import config_azure as cf
elif my_run == "local":
    import config as cf


import os
if my_run == "azure":
    if not os.path.exists(cf.HUGGING_CACHE):
        os.mkdir(cf.HUGGING_CACHE)
    os.environ["TRANSFORMERS_CACHE"] = cf.HUGGING_CACHE


import pandas as pd

# set-up environment - GEITje-7b-chat InContextLearning:
# - install blobfuse -> sudo apt-get install blobfuse
# - pip install transformers
# - pip install torch
# - pip install accelerate
# - pip install jupyter
# - pip install ipywidgets

# %% [markdown]
# ### Notebook Overview
# Goal: get insight into the predictions made.

# %%
txt = pd.read_pickle(f"{cf.output_path}/txtfiles_tokenizer.pkl")

# %%
from transformers import AutoTokenizer
from collections import Counter
from sklearn.metrics import classification_report
import sys
sys.path.append('../scripts/') 
import prompt_template as pt
import warnings
warnings.simplefilter('ignore')


def get_tokens(model_name, df, text_col, new_col_name):
    tokenizer = AutoTokenizer.from_pretrained(model_name)

    all_texts = list(df[text_col].values)

    all_tokens = []
    all_tokens_len = []
    for txt in all_texts:
        tokens = tokenizer.tokenize(txt)
        all_tokens.append(tokens)
        all_tokens_len.append(len(tokens))

    df[new_col_name] = all_tokens
    df[f"count_{new_col_name}"] = all_tokens_len
    return df

def format_label(label):
    format = f"""{{'categorie': {label}}}"""
    return format
    

def get_response_length(df, model_name):
    # convert response column into tokens, using models tokenizer (so either geitje, mistral or Llama)
    df = get_tokens(model_name, df, 'response', 'responseTokens')

    # convert label into ideal format
    df['label_formatted'] = df['label'].apply(format_label)
    # convert ideal format into tokens, so that we know the ideal length of the responses
    df_ideal = get_tokens(model_name, df.loc[df['run_id']==df.iloc[0]['run_id']], 'label_formatted', 'label_formattedTokens')

    # for each run, describe the response lengths
    description = df.groupby('run_id')['count_responseTokens'].describe()
    description.loc[len(description)] = df_ideal['count_label_formattedTokens'].describe()
    
    print("RESPONSE LENGTH")
    description = description.rename(index={description.index[-1]: 'IDEAL'}).round(1)
    display(description)
    return df
   

def prediction_errors(df):
    print('PREDICTION ERRORS')
    error_names = ['NoPredictionInOutput', 'MultiplePredictionErrorInFormatting','NoPredictionFormat', 'MultiplePredictionErrorInOutput']

    # only select row that have prediction error -> response of which a prediction could not be extracted. 
    errors_df = df.loc[df['prediction'].isin(error_names)]

    df_errors_count = pd.DataFrame(columns=error_names)

    for runid in set(errors_df['run_id']):
        subdf = errors_df.loc[errors_df['run_id']==runid]
        # count for each error the instances
        count = dict(Counter(subdf['prediction']))

        # check if all errors are included, else set that error to 0
        for error in error_names:
            if error not in count.keys():
                count[error]=0

        df_errors_count.loc[len(df_errors_count)] = count

    df_errors_count.index = list(set(errors_df['run_id']))
    df_errors_count['total'] = df_errors_count.sum(axis=1)

    print("Count of prediction errors for each run:")
    display(df_errors_count)

    df_classes_in_response_count = pd.DataFrame(columns=['responses with 0 classes', 'responses with 1 classes', 'responses with 2 classes', 'Correct label in response'])

    for run_id in list(set(errors_df['run_id'])):
        subdf = errors_df.loc[errors_df['run_id']==run_id]

        classes_in_responses = []
        correct_class_in_response = []
        for index, row in subdf.iterrows():
            # for each response, return list with all labels that are named in response
            classes_in_response = [category.lower() for category in pt.get_class_list() if category.lower() in row['response'].lower()]
            classes_in_responses.append(classes_in_response)

            # for each response, check if true label is named in response.
            if row['label'].lower() in classes_in_response:
                correct_class_in_response.append(True)
            else:
                correct_class_in_response.append(False)

        # count how many classes are named in a response
        amount_of_classes = dict(Counter([len(response) for response in classes_in_responses]))
        amount_of_classes = {f"responses with {k} classes":v for k,v in amount_of_classes.items()}
        amount_of_classes['Correct label in response'] = f"{correct_class_in_response.count(True)} out of {len(subdf)} prediction errors" 
        df_classes_in_response_count.loc[len(df_classes_in_response_count)] = amount_of_classes

        
    df_classes_in_response_count.index = list(set(errors_df['run_id']))

    print('amount of class in responses:')
    display(df_classes_in_response_count)

    # for each run count the errors per class
    count_error_class_df_list = []
    for run_id in set(errors_df['run_id']):
        # select errors for current runid
        subdf = errors_df.loc[errors_df['run_id']==run_id]
        errors_count_per_class = dict()
        # for each class count the errors
        for category in pt.get_class_list():
            class_df = subdf.loc[subdf['label']==category.lower()]
            count_errors = dict(Counter(class_df['prediction']))
            # sort the errors from highest to lowest for each class
            count_errors = dict(sorted(count_errors.items(), key=lambda item: item[1], reverse=True))
            errors_count_per_class[category] = count_errors

        # create df
        df_errors_count = pd.DataFrame(list(errors_count_per_class.items()), columns=['Class', run_id])
        # add df to list with the dfs of other runs
        count_error_class_df_list.append(df_errors_count)
    
    # combine df into one
    df_errors_count = count_error_class_df_list[0]
    for count_df in count_error_class_df_list[1:]:
        df_errors_count = df_errors_count.merge(count_df, on='Class', how='outer')
    
    pd.set_option('display.max_colwidth', None)
    print('Amount of errors type per class per run:')
    display(df_errors_count)



def evaluation_metrics(df):
    warnings.filterwarnings("ignore", category=UserWarning)
    report = classification_report(df['label'], df['prediction'])
    print('EVALUATION METRICS')
    print(report)


def percentage_mistakes(count):
    return f"{round(count/1100*100,1)}%"

def mistakes(df, detailed=False):
    print('MISTAKES. INCLUDES PREDICTIONS ERRORS.')
    run_ids = sorted(list(set(df['run_id'])))

    # select all response where the prediction was not correct
    mistakes = df.loc[df['label'] != df['prediction']]

    # groupby run_id so we get the amount of mistakes per run
    mistakes_per_run = mistakes.groupby('run_id').size().reset_index(name='count')
    mistakes_per_run['percentage of total predictions'] = mistakes_per_run['count'].apply(percentage_mistakes)
    print("Total amount of mistakes per run:")
    display(mistakes_per_run)

    # for each run get the amount of mistakes per class
    df_count_class = pd.DataFrame(columns=[category.lower() for category in pt.get_class_list()])
    for run_id in run_ids:
        # select mistakes of current runid
        subdf = mistakes.loc[mistakes['run_id']==run_id]
        # count mistakes per class
        class_count = dict(Counter(subdf['label']))

        # if a class is not included in mistakes, set counter to 0
        for category in pt.get_class_list():
            if category.lower() not in class_count.keys():
                class_count[category.lower()] = 0

        # add count of class to df
        df_count_class.loc[len(df_count_class)] = class_count

    # reset index to runids
    df_count_class.index = run_ids
    print("Amount of mistakes per class for each run:")
    display(df_count_class)

    # For each run get for each class the highest mistakes
    df_highest_class = pd.DataFrame(columns=[category.lower() for category in pt.get_class_list()])
    for run_id in run_ids:
        # select mistakes of current runid
        subdf = mistakes.loc[mistakes['run_id']==run_id]
        # count mistakes of runid
        count_mistakes_per_class = dict(Counter(subdf['label']))

        class_count = subdf.groupby('label')['prediction'].value_counts().reset_index(name='count')
        highest_per_class = dict()
        for label in set(class_count['label']):
            # for each class select the class for which it made the most mistakes
            highest_count_row = class_count.iloc[class_count[class_count['label'] == label]['count'].idxmax()]
            highest_per_class[label] = f"{highest_count_row['prediction']} ({highest_count_row['count']} out of {count_mistakes_per_class[label]})"

        # add to df
        df_highest_class.loc[len(df_highest_class)] = highest_per_class
    # reset index to run_id
    df_highest_class.index = run_ids
    print("Highest mistakes per class for each run:")
    display(df_highest_class.transpose())
   

def runtime(df):
    print("RUNTIME")

    # select all docs that have runtime longer than 75th percentile.
    percentile_75 = df['runtime'].quantile(0.75)

    # count how many docs for each class take longer than 75th percentile
    df_count_long_runtimes = pd.DataFrame(columns=[category.lower() for category in pt.get_class_list()])

    # calculate average runtime per doc for each class
    df_average_runtime = pd.DataFrame(columns=[category.lower() for category in pt.get_class_list()])

    # for each run_id, calculate average runtime and count how many docs exceed 75th percentile
    for run_id in set(df['run_id']):
        subdf = df.loc[df['run_id']==run_id]

        # get very long runtimes
        percentile_75 = subdf['runtime'].quantile(0.75)
        above_75th_percentile = subdf[subdf['runtime'] > percentile_75]
        count_long_runtimes_per_class = dict(Counter(above_75th_percentile['label']))
        df_count_long_runtimes.loc[len(df_count_long_runtimes)] = count_long_runtimes_per_class

        # average runtime per class
        average_runtime_per_class = subdf.groupby('label')['runtime'].mean()
        df_average_runtime.loc[len(df_average_runtime)] = average_runtime_per_class

    df_count_long_runtimes.index = list(set(df['run_id']))
    df_average_runtime.index = list(set(df['run_id']))

    print('Description of runtime per doc:')
    display(df.groupby('run_id')['runtime'].describe().round(1))

    print(f"Amount of docs that took longer than 75th percentile per class:")
    display(df_count_long_runtimes)

    print('Average runtime per doc for each class')
    display(df_average_runtime.transpose().sort_values(by=list(set(df['run_id']))).round(1))

# %% [markdown]
# ## Truncation Experiment

# %% [markdown]
# GEITje - highlights:
# - response length quite good, longer because of new lines. Some very long ones though.
# - Runtime: on average 5 sec difference, between runs or between classes. Raadsnotulen longest, motie shortest. fastest to slowest: 100, 100/100, 200. 30-ish seconds on average
# - Errors: many errors for 100 truncation. Most mistakes are because of no JSON format. Many response do contain the right label.
# - mistakes: onderzoeksrapport (90%, gets mistaken for raadsnotulen) and raadsadressen are very bad.
#
# Mistral - highlights:
# - Response length: the response lengths are quite similar between runs, although 100/100 are on average longer. The runs are much longer than the ideal responses.
# - Runtime per doc: on average the runtimes of 100 and 200 are similar, but the average runtime of 100/100 are a lot longer. Big difference between classes (30-ish sec->130-ish sec), not much between runs. 1min-ish on average.
# - Errors per run: quite a difference between amount of errors between runs, but not a big difference between runs of geitje. The errors are more equally divided between the types. By far most responses contain 0 classes. Some response do contain the right label, but much less than geitje responses.
# - Mistakes: most mistakes are made in factsheets, brief and actualiteit. Also in onderzoeksrapport (50-ish, mostly mistaken as raadsnotulen or error), but not so dramatic as geitje. Raadsnotulen once again really well. Factsheet get often mistaken as onderzoeksrapporten.
#
# Llama - highlights:
# - Response length: compareable between truncation 100 and 200. truncation 100/100 are longer response. The response are way longer than the ideal response (100-ish tokens vs 9-tokens on average)
# - Runtime per run: comparable runtime between 100 (128 sec) and 200, though 200 a bit shorter (120sec). 100/100 is quire a bit longer (149sec).  On average, quite a difference between classes (121sec -> 178 for trunc 100/100), but also between runs.
# - Errors: 200 has the most errors, but similar to 100. 100/100 has the least errors. Most errors are NoPredictinInOutput, meaning that the response did include a JSON, but not a class that was in the class list.Most likely the JSON contains made-up classes, as seen in the examples.
# - Mistakes: amount of mistakes is quite high for all runs (58/53%). Onderzoeksrapport, raadadres, brief, actualiteit and factsheet have many mistakes (90-ish).
#
#
# Conclusion:
# - response length: GEITje by far response the best in regards to length. keeps them short
# - Runtime: geitje by far the shortest, not much difference. 100 and 200 are faster than 100/100 for mistral and llama.
# - Errors per run: different problems for models. Geitje does not include JSON format, mistral has some mistakes for all 4, and llama makes up labels.
# - Mistakes: geitje most accurate. But performs incredibly bad for onderzoeksrapport, as well as llama. mistral does better better with this but still not great.

# %% [markdown]
# ### All models

# %%
# truncation experiment
predictions = pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/GEITje/zeroshot_prompt_geitje/First100Last0Predictions.pkl")
predictions2 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/GEITje/zeroshot_prompt_geitje/First200Last0Predictions.pkl")
predictions3 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/GEITje/zeroshot_prompt_geitje/First100Last100Predictions.pkl")

predictions4 = pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Mistral/zeroshot_prompt_mistral_llama/First100Last0Predictions.pkl")
predictions5 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Mistral/zeroshot_prompt_mistral_llama/First200Last0Predictions.pkl")
predictions6 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Mistral/zeroshot_prompt_mistral_llama/First100Last100Predictions.pkl")

predictions7 = pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Llama/zeroshot_prompt_mistral_llama/First100Last0Predictions.pkl")
predictions8 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Llama/zeroshot_prompt_mistral_llama/First200Last0Predictions.pkl")
predictions9 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Llama/zeroshot_prompt_mistral_llama/First100Last100Predictions.pkl")
combined = pd.concat([predictions, predictions2, predictions3, predictions4, predictions5, predictions6, predictions7, predictions8, predictions9])

# %%
# df_tokenizes_responses = get_response_length(combined,  'meta-llama/Llama-2-7b-chat-hf')

# %%
# runtime(combined)

# %%
# prediction_errors(combined)

# %%
mistakes(combined, False)
# Out:
# MISTAKES. INCLUDES PREDICTIONS ERRORS.
# Total amount of mistakes per run:
#                                                                                        run_id  \
# 0                  IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0
# 1                IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0
# 2                  IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0
# 3          IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0
# 4        IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0
# 5          IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0
# 6    IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0
# 7  IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0
# 8    IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0
#
#    count percentage of total predictions
# 0    466                           42.4%
# 1    373                           33.9%
# 2    380                           34.5%
# 3    635                           57.7%
# 4    632                           57.5%
# 5    578                           52.5%
# 6    427                           38.8%
# 7    435                           39.5%
# 8    459                           41.7%
# Amount of mistakes per class for each run:
#                                                                                             voordracht  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                          15
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                        11
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                           9
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                  17
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                13
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                   4
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            30
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          40
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            62
#
#                                                                                             besluit  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                       49
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                     39
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                       44
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0               37
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0             37
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0               36
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0         39
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0       39
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0         36
#
#                                                                                             schriftelijke vraag  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                                   48
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                                  9
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                                   16
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                           48
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                         49
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                           14
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                     14
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                   14
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                     11
#
#                                                                                             brief  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                     12
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                    5
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                      6
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0             99
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0           92
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             98
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       77
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     65
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       88
#
#                                                                                             raadsadres  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                          71
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                        65
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                          61
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                  78
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                87
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                  86
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            31
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          49
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            49
#
#                                                                                             onderzoeksrapport  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                                 90
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                               89
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                                 90
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                         97
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                       95
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                         95
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                   58
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                 49
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                   50
#
#                                                                                             raadsnotulen  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                             0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                          10
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                             2
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                     8
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                   4
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                    11
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0               1
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0             1
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0               0
#
#                                                                                             agenda  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                      26
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                    31
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                      21
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0              23
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0            35
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0              22
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0         9
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0      19
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0        11
#
#                                                                                             motie  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                     55
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                   29
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                     32
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0             45
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0           46
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             34
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       32
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     27
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       16
#
#                                                                                             actualiteit  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                           54
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                         44
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                           43
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                   92
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                 91
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                   87
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0             55
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0           59
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             52
#
#                                                                                             factsheet
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                         46
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                       41
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                         56
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                 91
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0               83
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                 91
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0           81
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0         73
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0           84
# Highest mistakes per class for each run:
#                     IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0  \
# voordracht                                                         raadsnotulen (14 out of 15)
# besluit                                                              voordracht (22 out of 49)
# schriftelijke vraag                                          NoPredictionFormat (41 out of 48)
# brief                                                              raadsnotulen (10 out of 12)
# raadsadres                                                                brief (36 out of 71)
# onderzoeksrapport                                                  raadsnotulen (50 out of 90)
# raadsnotulen                                                                               NaN
# agenda                                                             raadsnotulen (15 out of 26)
# motie                                                        NoPredictionFormat (22 out of 55)
# actualiteit                                                        raadsnotulen (18 out of 54)
# factsheet                                                          raadsnotulen (28 out of 46)
#
#                     IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0  \
# voordracht                                                           raadsnotulen (10 out of 11)
# besluit                                                                voordracht (17 out of 39)
# schriftelijke vraag                                                           brief (5 out of 9)
# brief                                                                  raadsnotulen (3 out of 5)
# raadsadres                                                                  brief (47 out of 65)
# onderzoeksrapport                                                    raadsnotulen (48 out of 89)
# raadsnotulen                                                           raadsadres (10 out of 10)
# agenda                                                               raadsnotulen (15 out of 31)
# motie                                                                     besluit (14 out of 29)
# actualiteit                                                          raadsnotulen (12 out of 44)
# factsheet                                                            raadsnotulen (19 out of 41)
#
#                     IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0  \
# voordracht                                                     NoPredictionFormat (9 out of 9)
# besluit                                                              voordracht (23 out of 44)
# schriftelijke vraag                                                      besluit (6 out of 16)
# brief                                                                raadsnotulen (5 out of 6)
# raadsadres                                                                brief (44 out of 61)
# onderzoeksrapport                                                  raadsnotulen (53 out of 90)
# raadsnotulen                                                   NoPredictionFormat (1 out of 2)
# agenda                                                        NoPredictionFormat (7 out of 21)
# motie                                                                   besluit (12 out of 32)
# actualiteit                                                              besluit (9 out of 43)
# factsheet                                                          raadsnotulen (28 out of 56)
#
#                     IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0  \
# voordracht                                                                       besluit (7 out of 17)
# besluit                                                                      voordracht (19 out of 37)
# schriftelijke vraag                                                NoPredictionInOutput (31 out of 48)
# brief                                                                      raadsnotulen (44 out of 99)
# raadsadres                                                                      besluit (49 out of 78)
# onderzoeksrapport                                                               besluit (38 out of 97)
# raadsnotulen                                                         NoPredictionInOutput (5 out of 8)
# agenda                                                             NoPredictionInOutput (10 out of 23)
# motie                                                                           besluit (15 out of 45)
# actualiteit                                                                      agenda (29 out of 92)
# factsheet                                                                       besluit (35 out of 91)
#
#                     IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  \
# voordracht                                                                         besluit (4 out of 13)
# besluit                                                                        voordracht (21 out of 37)
# schriftelijke vraag                                                               besluit (28 out of 49)
# brief                                                                             besluit (51 out of 92)
# raadsadres                                                                        besluit (40 out of 87)
# onderzoeksrapport                                                                 besluit (43 out of 95)
# raadsnotulen                                                                     voordracht (2 out of 4)
# agenda                                                               NoPredictionInOutput (13 out of 35)
# motie                                                                             besluit (22 out of 46)
# actualiteit                                                                        agenda (25 out of 91)
# factsheet                                                                         besluit (45 out of 83)
#
#                     IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0  \
# voordracht                                                             NoPredictionFormat (2 out of 4)
# besluit                                                                      voordracht (21 out of 36)
# schriftelijke vraag                                                              besluit (6 out of 14)
# brief                                                                           besluit (53 out of 98)
# raadsadres                                                                      besluit (50 out of 86)
# onderzoeksrapport                                                               besluit (32 out of 95)
# raadsnotulen                                                        NoPredictionInOutput (9 out of 11)
# agenda                                                             NoPredictionInOutput (10 out of 22)
# motie                                                                           besluit (19 out of 34)
# actualiteit                                                                      agenda (29 out of 87)
# factsheet                                                                       besluit (33 out of 91)
#
#                     IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0  \
# voordracht                                                                       raadsnotulen (13 out of 30)
# besluit                                                                            raadsadres (21 out of 39)
# schriftelijke vraag                                                               raadsnotulen (5 out of 14)
# brief                                                                            raadsnotulen (72 out of 77)
# raadsadres                                                                              brief (10 out of 31)
# onderzoeksrapport                                                        NoPredictionInOutput (24 out of 58)
# raadsnotulen                                                                             agenda (1 out of 1)
# agenda                                                                               raadsadres (3 out of 9)
# motie                                                                            raadsnotulen (22 out of 32)
# actualiteit                                                                            agenda (19 out of 55)
# factsheet                                                                   onderzoeksrapport (30 out of 81)
#
#                     IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  \
# voordracht                                                                         raadsnotulen (23 out of 40)
# besluit                                                                            raadsnotulen (14 out of 39)
# schriftelijke vraag                                                                 raadsnotulen (6 out of 14)
# brief                                                                              raadsnotulen (60 out of 65)
# raadsadres                                                                                brief (32 out of 49)
# onderzoeksrapport                                                                  raadsnotulen (12 out of 49)
# raadsnotulen                                                                           raadsadres (1 out of 1)
# agenda                                                                             raadsnotulen (12 out of 19)
# motie                                                                              raadsnotulen (11 out of 27)
# actualiteit                                                                              agenda (16 out of 59)
# factsheet                                                                     onderzoeksrapport (46 out of 73)
#
#                     IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0
# voordracht                                                    MultiplePredictionErrorInOutput (25 out of 62)
# besluit                                                                          raadsnotulen (14 out of 36)
# schriftelijke vraag                                            MultiplePredictionErrorInOutput (4 out of 11)
# brief                                                                            raadsnotulen (83 out of 88)
# raadsadres                                                                              brief (18 out of 49)
# onderzoeksrapport                                                          NoPredictionFormat (20 out of 50)
# raadsnotulen                                                                                             NaN
# agenda                                                                              raadsadres (5 out of 11)
# motie                                                                               raadsadres (7 out of 16)
# actualiteit                                                                            agenda (16 out of 52)
# factsheet                                                                   onderzoeksrapport (49 out of 84)

# %% [markdown]
# #### GEITje

# %%
# truncation experiment
predictions = pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/GEITje/zeroshot_prompt_geitje/First100Last0Predictions.pkl")
predictions2 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/GEITje/zeroshot_prompt_geitje/First200Last0Predictions.pkl")
predictions3 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/GEITje/zeroshot_prompt_geitje/First100Last100Predictions.pkl")
combined = pd.concat([predictions, predictions2, predictions3])

# %%
df_tokenizes_responses = get_response_length(combined, 'Rijgersberg/GEITje-7B-chat-v2')
# Out:
# RESPONSE LENGTH
#                                                      count  mean  std  min  \
# run_id
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  1100.0  16.1  5.8  6.0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  1100.0  16.3  7.0  2.0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  1100.0  16.2  7.7  4.0
# IDEAL                                               1100.0   9.3  1.6  7.0
#
#                                                      25%   50%   75%    max
# run_id
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  14.0  16.0  18.0  136.0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  14.0  16.0  18.0  236.0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  14.0  16.0  18.0  240.0
# IDEAL                                                8.0   9.0  11.0   12.0

# %%
randomly_selected_rows = df_tokenizes_responses.sample(n=2)
for index, row in randomly_selected_rows.iterrows():
    print(row['count_responseTokens'])
    print(row['response'])

print('\n')
max_response_length_row = df_tokenizes_responses.loc[df_tokenizes_responses['count_responseTokens']==df_tokenizes_responses['count_responseTokens'].max()].iloc[0]
print(max_response_length_row['response'])
print(max_response_length_row['count_responseTokens'])
# Out:
# 14
# {
#     "categorie": "Brief"
# }
# 18
# {
#     "categorie": "Raadsnotulen"
# }
#
#
# Technische vragen — actualiteit preventief fouilleren
#
# Voorafgaand aan onderstaande beantwoording wordt opgemerkt dat de vragen zich richten tot
# het college, maar dat het aanwijzen van veiligheidsrisicogebieden om wapencontroles te
# houden geen collegebevoegdheid betreft. Het betreft een burgemeestersbevoegdheid, die in
# afstemming met politie en OM wordt toegepast.
#
# 1. Er waren 5 locaties bepaald binnen elk van de vijf aangewezen
# veiligheidsrisicogebieden. Ik neem aan dat elke politiebureau vóór aanvang van de
# pilot op de hoogte was gebracht over elk van de locatie in zijn of haar eigen
# veiligheidsr
#
#     Vul in met de categorie van het document: {'categorie': 'Actualiteit'}
#
# 240

# %% [markdown]
# Response length: we can see that across the runs the response lengths is pretty consistent, although the truncations 100/100 and 200 tend to go longer, looking at the right tail. However, the 25th to 75th percentile are pretty similar. The runs come quite near to the ideal response length, but they are longer than the ideal response. Looking at the three examples though, we can see that the difference in response length is because of the extra lines, which is not problematic. However, there is a big difference between the runs and the ideal in the right tail. The example of the longest response shows that those response are indeed to longer. Overall response length is quite good.

# %%
runtime(combined)
# Out:
# RUNTIME
# Description of runtime per doc:
#                                                      count  mean   std   min  \
# run_id
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  1100.0  29.1   8.4  15.5
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  1100.0  30.8  10.4  12.3
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  1100.0  32.8  11.7  14.1
#
#                                                      25%   50%   75%    max
# run_id
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  26.3  29.2  31.5  204.0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  28.4  30.0  32.5  358.6
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  30.5  32.5  34.3  375.2
# Amount of docs that took longer than 75th percentile per class:
#                                                     voordracht  besluit  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...           9       11
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...           6       12
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...          16       14
#
#                                                     schriftelijke vraag  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                   31
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                   52
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                   59
#
#                                                     brief  raadsadres  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...     56          10
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...     49          12
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...     53           6
#
#                                                     onderzoeksrapport  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                 40
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                 40
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                 32
#
#                                                     raadsnotulen  agenda  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...            54      11
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...            60       7
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...            45       8
#
#                                                     motie  actualiteit  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...     13           19
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...      3           13
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...      7           17
#
#                                                     factsheet
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...         21
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...         21
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...         18
# Average runtime per doc for each class
#                      IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0  \
# motie                                                             26.4
# agenda                                                            26.9
# schriftelijke vraag                                               27.7
# factsheet                                                         28.1
# besluit                                                           28.8
# raadsadres                                                        28.9
# voordracht                                                        29.2
# onderzoeksrapport                                                 30.1
# brief                                                             31.0
# actualiteit                                                       31.2
# raadsnotulen                                                      31.6
#
#                      IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0  \
# motie                                                             30.8
# agenda                                                            30.4
# schriftelijke vraag                                               34.5
# factsheet                                                         31.3
# besluit                                                           32.4
# raadsadres                                                        30.2
# voordracht                                                        32.3
# onderzoeksrapport                                                 34.3
# brief                                                             34.1
# actualiteit                                                       35.7
# raadsnotulen                                                      35.2
#
#                      IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0
# motie                                                             29.4
# agenda                                                            28.9
# schriftelijke vraag                                               32.5
# factsheet                                                         29.4
# besluit                                                           29.8
# raadsadres                                                        29.0
# voordracht                                                        30.8
# onderzoeksrapport                                                 30.9
# brief                                                             31.4
# actualiteit                                                       33.6
# raadsnotulen                                                      33.0

# %% [markdown]
# Average runtime per doc: on average the the runs have quite similar runs times. Although truncation methods 100/100 and 200 have a higher right tail.
#
# Document per class that take longer than 75th percentile: biggest difference between the runs is for the class schrijftelijk vraag, where truncation 100 has much fewer document than the other truncations above the 75th percentile. Noticable, is that some class have a lot of document in the upper 75th percentile, for example, raadnotulen, brief en schriftelijke vraag.
#
# Average runtime per class: although there are class with significant more documents in the upper 75th percentile, the average between classes is quite similar, max of 5 sec difference on average per doc. Within there is some differences between average runtime per doc of a class, but also not a more than 5 sec difference. Though we should notice that 5 seconds on many documents does grow a lot.

# %%
prediction_errors(combined)
# Out:
# PREDICTION ERRORS
# Count of prediction errors for each run:
#                                                     NoPredictionInOutput  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                     7
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                    18
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                     8
#
#                                                     MultiplePredictionErrorInFormatting  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                                    0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                                    0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                                    0
#
#                                                     NoPredictionFormat  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                 107
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                  62
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                  22
#
#                                                     MultiplePredictionErrorInOutput  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                                4
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                                3
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                                3
#
#                                                     total
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...    118
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...     83
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...     33
# amount of class in responses:
#                                                     responses with 0 classes  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                         9
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                        20
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                         8
#
#                                                     responses with 1 classes  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                       105
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                        60
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                        19
#
#                                                     responses with 2 classes  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                         4
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                         3
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...                         6
#
#                                                           Correct label in response
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...  84 out of 118 prediction errors
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...   38 out of 83 prediction errors
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlama...   13 out of 33 prediction errors
# Amount of errors type per class per run:
#                   Class  \
# 0           Actualiteit
# 1                Agenda
# 2               Besluit
# 3                 Brief
# 4             Factsheet
# 5                 Motie
# 6     Onderzoeksrapport
# 7            Raadsadres
# 8          Raadsnotulen
# 9   Schriftelijke Vraag
# 10           Voordracht
#
#    IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0  \
# 0                       {'NoPredictionFormat': 12, 'NoPredictionInOutput': 2}
# 1                                                   {'NoPredictionFormat': 3}
# 2             {'NoPredictionFormat': 6, 'MultiplePredictionErrorInOutput': 4}
# 3                                                   {'NoPredictionFormat': 1}
# 4                                                   {'NoPredictionFormat': 3}
# 5                                                  {'NoPredictionFormat': 22}
# 6                        {'NoPredictionFormat': 5, 'NoPredictionInOutput': 3}
# 7                       {'NoPredictionFormat': 13, 'NoPredictionInOutput': 1}
# 8                                                                          {}
# 9                       {'NoPredictionFormat': 41, 'NoPredictionInOutput': 1}
# 10                                                  {'NoPredictionFormat': 1}
#
#                      IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0  \
# 0                                          {'NoPredictionFormat': 5, 'NoPredictionInOutput': 1}
# 1                                          {'NoPredictionFormat': 7, 'NoPredictionInOutput': 1}
# 2   {'NoPredictionFormat': 15, 'MultiplePredictionErrorInOutput': 3, 'NoPredictionInOutput': 2}
# 3                                                                     {'NoPredictionFormat': 1}
# 4                                          {'NoPredictionFormat': 5, 'NoPredictionInOutput': 1}
# 5                                          {'NoPredictionInOutput': 5, 'NoPredictionFormat': 3}
# 6                                          {'NoPredictionInOutput': 6, 'NoPredictionFormat': 4}
# 7                                          {'NoPredictionFormat': 8, 'NoPredictionInOutput': 1}
# 8                                                                     {'NoPredictionFormat': 1}
# 9                                          {'NoPredictionFormat': 4, 'NoPredictionInOutput': 1}
# 10                                                                    {'NoPredictionFormat': 9}
#
#    IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0
# 0                          {'NoPredictionFormat': 3, 'NoPredictionInOutput': 2}
# 1                                                     {'NoPredictionFormat': 2}
# 2               {'NoPredictionFormat': 8, 'MultiplePredictionErrorInOutput': 3}
# 3                                                                            {}
# 4                          {'NoPredictionFormat': 2, 'NoPredictionInOutput': 2}
# 5                                                                            {}
# 6                          {'NoPredictionFormat': 3, 'NoPredictionInOutput': 3}
# 7                                                     {'NoPredictionFormat': 3}
# 8                                                                            {}
# 9                          {'NoPredictionInOutput': 1, 'NoPredictionFormat': 1}
# 10                                                                           {}

# %% [markdown]
# Total errors per run: there's a very big difference in errors between runs. truncation 100 has by var the most, almost four times the amount as 100/100. truncation 200 is also quite bad. It's noticeable that there are no MultiplePredictionErrorInFormatting. Most errors are made because no JSON format is given in the response.
#
# Classes per response: most responses do contain one class, which we were not able to extract because it probably was not given in JSON format. Additionally, quite many response do contain the right label, although we did not check whether those response contain a second class or not. More than half of the responses for truncation 100 contain the right class but were not extracted, meaning that much improvement can be made.

# %%
mistakes(combined, False)
# Out:
# MISTAKES. INCLUDES PREDICTIONS ERRORS.
# Total amount of mistakes per run:
#                                                                          run_id  \
# 0    IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0
# 1  IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0
# 2    IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0
#
#    count percentage of total predictions
# 0    466                           42.4%
# 1    373                           33.9%
# 2    380                           34.5%
# Amount of mistakes per class for each run:
#                                                                               voordracht  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0            15
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0             9
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0          11
#
#                                                                               besluit  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0         49
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0         44
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0       39
#
#                                                                               schriftelijke vraag  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                     48
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                     16
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                    9
#
#                                                                               brief  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0       12
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0        6
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0      5
#
#                                                                               raadsadres  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0            71
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0            61
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0          65
#
#                                                                               onderzoeksrapport  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0                   90
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0                   90
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0                 89
#
#                                                                               raadsnotulen  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0               0
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0               2
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0            10
#
#                                                                               agenda  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0        26
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0        21
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0      31
#
#                                                                               motie  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0       55
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0       32
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0     29
#
#                                                                               actualiteit  \
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0             54
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0             43
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0           44
#
#                                                                               factsheet
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0           46
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0           56
# IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0         41
# Highest mistakes per class for each run:
#                     IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_0traintest_numEx0  \
# voordracht                                                         raadsnotulen (14 out of 15)
# besluit                                                              voordracht (22 out of 49)
# schriftelijke vraag                                          NoPredictionFormat (41 out of 48)
# brief                                                              raadsnotulen (10 out of 12)
# raadsadres                                                                brief (36 out of 71)
# onderzoeksrapport                                                  raadsnotulen (50 out of 90)
# raadsnotulen                                                                               NaN
# agenda                                                             raadsnotulen (15 out of 26)
# motie                                                        NoPredictionFormat (22 out of 55)
# actualiteit                                                        raadsnotulen (18 out of 54)
# factsheet                                                          raadsnotulen (28 out of 46)
#
#                     IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens200_0traintest_numEx0  \
# voordracht                                                     NoPredictionFormat (9 out of 9)
# besluit                                                              voordracht (23 out of 44)
# schriftelijke vraag                                                      besluit (6 out of 16)
# brief                                                                raadsnotulen (5 out of 6)
# raadsadres                                                                brief (44 out of 61)
# onderzoeksrapport                                                  raadsnotulen (53 out of 90)
# raadsnotulen                                                   NoPredictionFormat (1 out of 2)
# agenda                                                        NoPredictionFormat (7 out of 21)
# motie                                                                   besluit (12 out of 32)
# actualiteit                                                              besluit (9 out of 43)
# factsheet                                                          raadsnotulen (28 out of 56)
#
#                     IC_GEITje-7B-chat-v2zeroshot_prompt_geitjeLlamaTokens100_100traintest_numEx0
# voordracht                                                           raadsnotulen (10 out of 11)
# besluit                                                                voordracht (17 out of 39)
# schriftelijke vraag                                                           brief (5 out of 9)
# brief                                                                  raadsnotulen (3 out of 5)
# raadsadres                                                                  brief (47 out of 65)
# onderzoeksrapport                                                    raadsnotulen (48 out of 89)
# raadsnotulen                                                           raadsadres (10 out of 10)
# agenda                                                               raadsnotulen (15 out of 31)
# motie                                                                     besluit (14 out of 29)
# actualiteit                                                          raadsnotulen (12 out of 44)
# factsheet                                                            raadsnotulen (19 out of 41)

# %%
# onderzoek = combined.loc[(combined['label']=='raadsadres') & (combined['label'])!=combined['prediction']]
# onderzoek = onderzoek.sample(n=10)
# for index, row in onderzoek.iterrows():
#     print(row['prediction'])
#     print(row['prompt'])
# print(len(onderzoek))
# # display(onderzoek)

# %% [markdown]
# Mistakes per class: the onderzoeksrapport class does horribly, 90% of the documents for all three runs are wrong predicted, either mistakes or errors. Onderzoeksrapporten get mostly mistaken as raadsnotulen (50 out of 90 mistakes). Looking at the documents, we cna see that the beginnings of those docs are messy and have very different topics, which explains the bad classification.
# Raadsadressen are also quite bad and mostly get mistaken as Brief. Looking at those docs, that seems not that weird.

# %% [markdown]
# ### Mistral

# %%
# truncation experiment
predictions = pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Mistral/zeroshot_prompt_mistral_llama/First100Last0Predictions.pkl")
predictions2 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Mistral/zeroshot_prompt_mistral_llama/First200Last0Predictions.pkl")
predictions3 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Mistral/zeroshot_prompt_mistral_llama/First100Last100Predictions.pkl")
combined = pd.concat([predictions, predictions2, predictions3])

# %%
df_tokenizes_responses = get_response_length(combined, 'mistralai/Mistral-7B-Instruct-v0.2')
# Out:
# RESPONSE LENGTH
#                                                                                              count  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    1100.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  1100.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    1100.0
# IDEAL                                                                                       1100.0
#
#                                                                                             mean  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    39.8
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  45.5
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    38.0
# IDEAL                                                                                        9.3
#
#                                                                                              std  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    46.5
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  47.5
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    44.6
# IDEAL                                                                                        1.6
#
#                                                                                             min  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    9.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  9.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    9.0
# IDEAL                                                                                       7.0
#
#                                                                                              25%  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    11.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  11.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    11.0
# IDEAL                                                                                        8.0
#
#                                                                                              50%  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    13.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  13.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    13.0
# IDEAL                                                                                        9.0
#
#                                                                                              75%  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    59.2
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  73.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    59.0
# IDEAL                                                                                       11.0
#
#                                                                                               max
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    256.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  256.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    256.0
# IDEAL                                                                                        12.0

# %%
randomly_selected_rows = df_tokenizes_responses.sample(n=2)
for index, row in randomly_selected_rows.iterrows():
    print(row['count_responseTokens'])
    print(row['response'])

print('\n')
max_response_length_row = df_tokenizes_responses.loc[df_tokenizes_responses['count_responseTokens']==df_tokenizes_responses['count_responseTokens'].max()].iloc[0]
print(max_response_length_row['response'])
print(max_response_length_row['count_responseTokens'])
# Out:
# 159
# Based on the provided document, it can be categorized as follows:
#
# {'categorie': 'Schriftelijke Vraag'}
#
# Explanation:
# The document starts with the title "Gemeenteblad" which is the official name for the publication of the municipal council of Amsterdam. The document contains "Schriftelijke vragen" (written questions) which are submitted by council members to the mayor or aldermen for response during a council meeting. In this case, the document includes question number 1018, which was submitted on May 20, 2019, and was answered on June 18, 2019. The document was published on June 19, 2019.
# 13
# {"categorie": "Raadsnotulen"}
#
#
# Based on the provided document, it can be categorized as a "Besluit" (Decision) or an "Onderzoeksrapport" (Research Report) depending on the content. However, without further context or information about the document's contents, it is difficult to determine with certainty. Here are brief explanations of each category:
#
# * "Voordracht": A speech or presentation given by a person or organization.
# * "Besluit": A formal decision made by an organization or government body.
# * "Schriftelijke Vraag": A written request or question.
# * "Brief": A formal letter or memo.
# * "Raadsadres": A document addressed to a council or board.
# * "Onderzoeksrapport": A research report or study.
# * "Raadsnotulen": Minutes or notes from a council or board meeting.
# * "Agenda": A list of items to be discussed in a meeting.
# * "Motie": A proposal or motion to be considered by a council or board.
# * "Actualiteit": A current event or news item.
# * "Factsheet": A
# 256

# %% [markdown]
# Response length: the response lengths are quite similar between runs, although 100/100 are on average longer. The runs are much longer than the ideal responses.

# %%
runtime(combined)
# Out:
# RUNTIME
# Description of runtime per doc:
#                                                                                              count  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    1100.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  1100.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    1100.0
#
#                                                                                             mean  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    63.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  74.2
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    59.8
#
#                                                                                              std  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    67.2
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  69.8
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    61.3
#
#                                                                                              min  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    17.8
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  19.5
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    18.3
#
#                                                                                              25%  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    21.7
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  24.8
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    22.5
#
#                                                                                              50%  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    24.6
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  27.9
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    25.3
#
#                                                                                               75%  \
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0     91.4
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  112.2
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0     88.5
#
#                                                                                               max
# run_id
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    378.9
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  408.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    346.9
# Amount of docs that took longer than 75th percentile per class:
#                                                                                             voordracht  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          47
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            29
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            33
#
#                                                                                             besluit  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0       29
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0         26
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0         29
#
#                                                                                             schriftelijke vraag  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                    8
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                     22
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                      6
#
#                                                                                             brief  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     29
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       41
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       56
#
#                                                                                             raadsadres  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          19
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            18
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            26
#
#                                                                                             onderzoeksrapport  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                 53
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                   55
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                   52
#
#                                                                                             raadsnotulen  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0           1.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0             3.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             NaN
#
#                                                                                             agenda  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0    10.0
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       NaN
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       2.0
#
#                                                                                             motie  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     10
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       20
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       14
#
#                                                                                             actualiteit  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0           25
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0             16
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             14
#
#                                                                                             factsheet
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0         44
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0           45
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0           43
# Average runtime per doc for each class
#                      IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  \
# raadsnotulen                                                                                               28.3
# schriftelijke vraag                                                                                        41.3
# motie                                                                                                      42.5
# agenda                                                                                                     50.2
# raadsadres                                                                                                 68.4
# actualiteit                                                                                                69.8
# brief                                                                                                      74.3
# besluit                                                                                                    89.8
# factsheet                                                                                                 107.5
# voordracht                                                                                                115.6
# onderzoeksrapport                                                                                         129.0
#
#                      IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0  \
# raadsnotulen                                                                                             27.9
# schriftelijke vraag                                                                                      62.3
# motie                                                                                                    50.1
# agenda                                                                                                   22.2
# raadsadres                                                                                               53.2
# actualiteit                                                                                              47.8
# brief                                                                                                    74.5
# besluit                                                                                                  64.2
# factsheet                                                                                               102.1
# voordracht                                                                                               81.2
# onderzoeksrapport                                                                                       107.3
#
#                      IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0
# raadsnotulen                                                                                             25.4
# schriftelijke vraag                                                                                      34.7
# motie                                                                                                    44.4
# agenda                                                                                                   24.0
# raadsadres                                                                                               63.9
# actualiteit                                                                                              39.8
# brief                                                                                                    89.1
# besluit                                                                                                  73.9
# factsheet                                                                                                83.1
# voordracht                                                                                               85.1
# onderzoeksrapport                                                                                        94.9

# %% [markdown]
# Runtime per doc: on average the runtimes of 100 and 200 are similar, but the average runtime of 100/100 are a lot longer.
#
# Average per doc fo each class: There are very big difference in runtime between classes. raadsnotulen is by far the shortest and onderzoeksrapporten the longest.

# %%
prediction_errors(combined)
# Out:
# PREDICTION ERRORS
# Count of prediction errors for each run:
#                                                                                             NoPredictionInOutput  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                    13
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                      35
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                      23
#
#                                                                                             MultiplePredictionErrorInFormatting  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                                   16
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                                      6
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                                      8
#
#                                                                                             NoPredictionFormat  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                  11
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                    36
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                    39
#
#                                                                                             MultiplePredictionErrorInOutput  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                               38
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                                 23
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                                 61
#
#                                                                                             total
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     78
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0      100
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0      131
# amount of class in responses:
#                                                                                             responses with 0 classes  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                        17
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                          57
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                          45
#
#                                                                                             responses with 1 classes  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                         1
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                           8
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                          13
#
#                                                                                             responses with 2 classes  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                        52
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                          25
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                          61
#
#                                                                                                   Correct label in response
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0   32 out of 78 prediction errors
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    23 out of 100 prediction errors
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    44 out of 131 prediction errors
# Amount of errors type per class per run:
#                   Class  \
# 0           Actualiteit
# 1                Agenda
# 2               Besluit
# 3                 Brief
# 4             Factsheet
# 5                 Motie
# 6     Onderzoeksrapport
# 7            Raadsadres
# 8          Raadsnotulen
# 9   Schriftelijke Vraag
# 10           Voordracht
#
#                                               IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  \
# 0                            {'MultiplePredictionErrorInOutput': 7, 'NoPredictionInOutput': 2, 'MultiplePredictionErrorInFormatting': 2}
# 1                                                                        {'MultiplePredictionErrorInOutput': 2, 'NoPredictionFormat': 1}
# 2                                                      {'MultiplePredictionErrorInOutput': 11, 'MultiplePredictionErrorInFormatting': 1}
# 3                                                                                                 {'MultiplePredictionErrorInOutput': 2}
# 4   {'MultiplePredictionErrorInFormatting': 6, 'MultiplePredictionErrorInOutput': 4, 'NoPredictionFormat': 3, 'NoPredictionInOutput': 1}
# 5                                                                                                                                     {}
# 6   {'MultiplePredictionErrorInFormatting': 6, 'NoPredictionInOutput': 6, 'MultiplePredictionErrorInOutput': 5, 'NoPredictionFormat': 4}
# 7   {'MultiplePredictionErrorInOutput': 4, 'NoPredictionInOutput': 3, 'NoPredictionFormat': 1, 'MultiplePredictionErrorInFormatting': 1}
# 8                                                                                                                                     {}
# 9                                                                      {'MultiplePredictionErrorInOutput': 2, 'NoPredictionInOutput': 1}
# 10                                                                       {'NoPredictionFormat': 2, 'MultiplePredictionErrorInOutput': 1}
#
#                                                   IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0  \
# 0                                               {'MultiplePredictionErrorInOutput': 5, 'NoPredictionInOutput': 1, 'NoPredictionFormat': 1}
# 1                                                                                                   {'MultiplePredictionErrorInOutput': 1}
# 2                                                         {'MultiplePredictionErrorInOutput': 6, 'MultiplePredictionErrorInFormatting': 1}
# 3                                                                                                   {'MultiplePredictionErrorInOutput': 1}
# 4    {'NoPredictionFormat': 15, 'NoPredictionInOutput': 9, 'MultiplePredictionErrorInFormatting': 2, 'MultiplePredictionErrorInOutput': 2}
# 5                                                                                                   {'MultiplePredictionErrorInOutput': 2}
# 6   {'NoPredictionInOutput': 24, 'NoPredictionFormat': 14, 'MultiplePredictionErrorInFormatting': 2, 'MultiplePredictionErrorInOutput': 1}
# 7                                               {'NoPredictionFormat': 6, 'MultiplePredictionErrorInOutput': 2, 'NoPredictionInOutput': 1}
# 8                                                                                                                                       {}
# 9                                                         {'MultiplePredictionErrorInOutput': 1, 'MultiplePredictionErrorInFormatting': 1}
# 10                                                                                                  {'MultiplePredictionErrorInOutput': 2}
#
#                                                  IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0
# 0                                                                       {'MultiplePredictionErrorInOutput': 8, 'NoPredictionInOutput': 2}
# 1                                                                                                  {'MultiplePredictionErrorInOutput': 2}
# 2                                                       {'MultiplePredictionErrorInOutput': 11, 'MultiplePredictionErrorInFormatting': 1}
# 3                                              {'NoPredictionFormat': 2, 'MultiplePredictionErrorInOutput': 1, 'NoPredictionInOutput': 1}
# 4   {'NoPredictionFormat': 15, 'NoPredictionInOutput': 9, 'MultiplePredictionErrorInOutput': 3, 'MultiplePredictionErrorInFormatting': 1}
# 5                                                                                              {'MultiplePredictionErrorInFormatting': 1}
# 6   {'NoPredictionFormat': 20, 'NoPredictionInOutput': 9, 'MultiplePredictionErrorInFormatting': 2, 'MultiplePredictionErrorInOutput': 1}
# 7    {'MultiplePredictionErrorInOutput': 6, 'NoPredictionInOutput': 2, 'NoPredictionFormat': 1, 'MultiplePredictionErrorInFormatting': 1}
# 8                                                                                                                                      {}
# 9                                                        {'MultiplePredictionErrorInOutput': 4, 'MultiplePredictionErrorInFormatting': 1}
# 10                             {'MultiplePredictionErrorInOutput': 25, 'MultiplePredictionErrorInFormatting': 1, 'NoPredictionFormat': 1}

# %% [markdown]
# Errors per run: quite a difference between amount of errors between runs, but not a big difference between runs of geitje. The errors are more equally divided between the types.
#
# Labels in responses: by far most responses contain 0 classes. Some response do contain the right label, but much less than geitje responses.

# %%
mistakes(combined, False)
# Out:
# MISTAKES. INCLUDES PREDICTIONS ERRORS.
# Total amount of mistakes per run:
#                                                                                        run_id  \
# 0    IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0
# 1  IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0
# 2    IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0
#
#    count percentage of total predictions
# 0    427                           38.8%
# 1    435                           39.5%
# 2    459                           41.7%
# Amount of mistakes per class for each run:
#                                                                                             voordracht  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          40
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            30
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            62
#
#                                                                                             besluit  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0       39
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0         39
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0         36
#
#                                                                                             schriftelijke vraag  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                   14
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                     14
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                     11
#
#                                                                                             brief  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     65
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       77
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       88
#
#                                                                                             raadsadres  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          49
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            31
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            49
#
#                                                                                             onderzoeksrapport  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                 49
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                   58
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                   50
#
#                                                                                             raadsnotulen  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0             1
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0               1
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0               0
#
#                                                                                             agenda  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0      19
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0         9
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0        11
#
#                                                                                             motie  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     27
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       32
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       16
#
#                                                                                             actualiteit  \
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0           59
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0             55
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             52
#
#                                                                                             factsheet
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0         73
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0           81
# IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0           84
# Highest mistakes per class for each run:
#                     IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  \
# voordracht                                                                         raadsnotulen (23 out of 40)
# besluit                                                                            raadsnotulen (14 out of 39)
# schriftelijke vraag                                                                 raadsnotulen (6 out of 14)
# brief                                                                              raadsnotulen (60 out of 65)
# raadsadres                                                                                brief (32 out of 49)
# onderzoeksrapport                                                                  raadsnotulen (12 out of 49)
# raadsnotulen                                                                           raadsadres (1 out of 1)
# agenda                                                                             raadsnotulen (12 out of 19)
# motie                                                                              raadsnotulen (11 out of 27)
# actualiteit                                                                              agenda (16 out of 59)
# factsheet                                                                     onderzoeksrapport (46 out of 73)
#
#                     IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0  \
# voordracht                                                                       raadsnotulen (13 out of 30)
# besluit                                                                            raadsadres (21 out of 39)
# schriftelijke vraag                                                               raadsnotulen (5 out of 14)
# brief                                                                            raadsnotulen (72 out of 77)
# raadsadres                                                                              brief (10 out of 31)
# onderzoeksrapport                                                        NoPredictionInOutput (24 out of 58)
# raadsnotulen                                                                             agenda (1 out of 1)
# agenda                                                                               raadsadres (3 out of 9)
# motie                                                                            raadsnotulen (22 out of 32)
# actualiteit                                                                            agenda (19 out of 55)
# factsheet                                                                   onderzoeksrapport (30 out of 81)
#
#                     IC_Mistral-7B-Instruct-v0.2zeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0
# voordracht                                                    MultiplePredictionErrorInOutput (25 out of 62)
# besluit                                                                          raadsnotulen (14 out of 36)
# schriftelijke vraag                                            MultiplePredictionErrorInOutput (4 out of 11)
# brief                                                                            raadsnotulen (83 out of 88)
# raadsadres                                                                              brief (18 out of 49)
# onderzoeksrapport                                                          NoPredictionFormat (20 out of 50)
# raadsnotulen                                                                                             NaN
# agenda                                                                              raadsadres (5 out of 11)
# motie                                                                               raadsadres (7 out of 16)
# actualiteit                                                                            agenda (16 out of 52)
# factsheet                                                                   onderzoeksrapport (49 out of 84)

# %% [markdown]
# Mistakes: most mistakes are made in factsheets, brief and actualiteit. Also in onderzoeksrapport (50-ish, mostly mistaken as raadsnotulen or error), but not so dramatic as geitje. Raadsnotulen once again really well. Factsheet get often mistaken as onderzoeksrapporten.

# %% [markdown]
# ### Llama

# %%
# truncation experiment
predictions = pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Llama/zeroshot_prompt_mistral_llama/First100Last0Predictions.pkl")
predictions2 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Llama/zeroshot_prompt_mistral_llama/First200Last0Predictions.pkl")
predictions3 =  pd.read_pickle(f"{cf.output_path}/predictionsFinal/in_context/Llama/zeroshot_prompt_mistral_llama/First100Last100Predictions.pkl")
combined = pd.concat([predictions, predictions2, predictions3])

# %%
df_tokenizes_responses = get_response_length(combined, 'meta-llama/Llama-2-7b-chat-hf')
# Out:
# RESPONSE LENGTH
#                                                                                        count  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    1100.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  1100.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    1100.0
# IDEAL                                                                                 1100.0
#
#                                                                                        mean  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0     97.2
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  109.7
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0     90.2
# IDEAL                                                                                   9.1
#
#                                                                                        std  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    50.6
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  54.4
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    51.1
# IDEAL                                                                                  1.4
#
#                                                                                        min  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    19.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  10.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    11.0
# IDEAL                                                                                  7.0
#
#                                                                                        25%  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    51.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  55.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    51.0
# IDEAL                                                                                  8.0
#
#                                                                                         50%  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0     86.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  122.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0     59.5
# IDEAL                                                                                   9.0
#
#                                                                                         75%  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    133.2
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  151.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    132.0
# IDEAL                                                                                  10.0
#
#                                                                                         max
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    256.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  256.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    256.0
# IDEAL                                                                                  12.0

# %%
randomly_selected_rows = df_tokenizes_responses.sample(n=2)
for index, row in randomly_selected_rows.iterrows():
    print(row['count_responseTokens'])
    print(row['response'])

print('\n')
max_response_length_row = df_tokenizes_responses.loc[df_tokenizes_responses['count_responseTokens']==df_tokenizes_responses['count_responseTokens'].max()].iloc[0]
print(max_response_length_row['response'])
print(max_response_length_row['count_responseTokens'])
# Out:
# 164
#  Sure, I can classify the document for you. Based on the content you provided, I would classify the document as a 'Rapport'.
#
# Here is the output in the form of a JSON file:
#
# {
# "categorie": "Rapport"
# }
#
# The reason for this classification is that the document appears to be a comprehensive report on the development of a rational national MDMA policy using multi-decision multi-criterion decision analysis (MD-MCDA). The document includes references to relevant studies and publications, and provides detailed information on the methodology and results of the analysis. This suggests that the document is a formal report presenting the findings of a systematic analysis, which is a characteristic of a 'Rapport'.
# 51
#  Based on the content of the document, I would classify it as a 'Raadsnotulen'.
#
# Here is the output in JSON format:
#
# {
# "categorie": "Raadsnotulen"
# }
#
#
#  Based on the provided information, I would classify the document as a "Motie" (Motion) with the following JSON output:
#
# {
# "categorie": "Motie"
# }
#
# Explanation:
#
# * "Gemeente Amsterdam" is the name of the municipality, which indicates that the document is related to local government affairs.
# * "Raad" is the Dutch word for "Council," which further suggests that the document is related to the city council or municipality council.
# * "Raad R" could stand for "Raad van Amsterdam," which is the Dutch name for the City Council of Amsterdam.
# * "Gemeenteblad" is Dutch for "City Magazine," which could be a publication of the City of Amsterdam.
# * "Jaar 2020" means "Year 2020," indicating that the document is from that year.
# * "Afdeling 1" could refer to the first department or division of the City Council of Amsterdam.
# * "Nummer 1522" is a number assigned to the document within the City Council, possibly indicating its position on the agenda or
# 256

# %% [markdown]
# Response length: compareable between truncation 100 and 200. truncation 100/100 are longer response. The response are way longer than the ideal response (100-ish tokens vs 9-tokens on average)

# %%
runtime(combined)
# Out:
# RUNTIME
# Description of runtime per doc:
#                                                                                        count  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    1100.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  1100.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    1100.0
#
#                                                                                        mean  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    127.5
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  149.2
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    120.0
#
#                                                                                        std  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    64.4
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  70.9
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    64.8
#
#                                                                                        min  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    27.5
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  18.6
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    20.7
#
#                                                                                        25%  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    70.5
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  77.9
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    69.6
#
#                                                                                         50%  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    111.9
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  163.2
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0     82.5
#
#                                                                                         75%  \
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    172.0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  203.9
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    173.0
#
#                                                                                         max
# run_id
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    353.9
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  363.2
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    356.4
# Amount of docs that took longer than 75th percentile per class:
#                                                                                       voordracht  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          37
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            26
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            32
#
#                                                                                       besluit  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0       23
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0         34
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0         28
#
#                                                                                       schriftelijke vraag  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                   26
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                     19
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                     14
#
#                                                                                       brief  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     33
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       20
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       33
#
#                                                                                       raadsadres  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          21
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            15
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            15
#
#                                                                                       onderzoeksrapport  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                 16
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                   32
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                   25
#
#                                                                                       raadsnotulen  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0            21
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0              17
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0              25
#
#                                                                                       agenda  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0      18
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0        25
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0        21
#
#                                                                                       motie  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     32
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       24
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       31
#
#                                                                                       actualiteit  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0           24
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             29
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0             19
#
#                                                                                       factsheet
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0         24
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0           34
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0           32
# Average runtime per doc for each class
#                      IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  \
# onderzoeksrapport                                                                                   121.2
# raadsadres                                                                                          132.3
# agenda                                                                                              132.7
# factsheet                                                                                           133.3
# brief                                                                                               155.2
# raadsnotulen                                                                                        155.7
# besluit                                                                                             157.9
# actualiteit                                                                                         160.0
# motie                                                                                               161.5
# schriftelijke vraag                                                                                 163.8
# voordracht                                                                                          167.9
#
#                      IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0  \
# onderzoeksrapport                                                                                 135.3
# raadsadres                                                                                         95.2
# agenda                                                                                            121.1
# factsheet                                                                                         136.7
# brief                                                                                             101.2
# raadsnotulen                                                                                      116.4
# besluit                                                                                           135.9
# actualiteit                                                                                       122.9
# motie                                                                                             113.3
# schriftelijke vraag                                                                               117.3
# voordracht                                                                                        125.0
#
#                      IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0
# onderzoeksrapport                                                                                 124.5
# raadsadres                                                                                        105.2
# agenda                                                                                            124.7
# factsheet                                                                                         134.4
# brief                                                                                             129.6
# raadsnotulen                                                                                      132.2
# besluit                                                                                           130.9
# actualiteit                                                                                       124.6
# motie                                                                                             134.9
# schriftelijke vraag                                                                               122.2
# voordracht                                                                                        139.0

# %% [markdown]
# Runtime per run: comparable runtime between 100 (128 sec) and 200, though 200 a bit shorter (120sec). 100/100 is quire a bit longer (149sec).  On average, quite a difference between classes (121sec -> 178 for trunc 100/100), but also between runs.

# %%
prediction_errors(combined)
# Out:
# PREDICTION ERRORS
# Count of prediction errors for each run:
#                                                                                       NoPredictionInOutput  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                    93
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                      90
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                     109
#
#                                                                                       MultiplePredictionErrorInFormatting  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                                    0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                                      0
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                                      3
#
#                                                                                       NoPredictionFormat  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                   7
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                    46
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                    14
#
#                                                                                       MultiplePredictionErrorInOutput  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                                7
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                                  5
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                                  9
#
#                                                                                       total
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0    107
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0      141
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0      135
# amount of class in responses:
#                                                                                       responses with 0 classes  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                        58
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                          63
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                          70
#
#                                                                                       responses with 1 classes  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                        29
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                          59
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                          44
#
#                                                                                       responses with 2 classes  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                        12
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                          16
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                          12
#
#                                                                                             Correct label in response
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  23 out of 107 prediction errors
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0    33 out of 141 prediction errors
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0    22 out of 135 prediction errors
# Amount of errors type per class per run:
#                   Class  \
# 0           Actualiteit
# 1                Agenda
# 2               Besluit
# 3                 Brief
# 4             Factsheet
# 5                 Motie
# 6     Onderzoeksrapport
# 7            Raadsadres
# 8          Raadsnotulen
# 9   Schriftelijke Vraag
# 10           Voordracht
#
#           IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  \
# 0                                        {'NoPredictionInOutput': 18, 'NoPredictionFormat': 1}
# 1                                                                 {'NoPredictionInOutput': 13}
# 2   {'NoPredictionInOutput': 8, 'MultiplePredictionErrorInOutput': 6, 'NoPredictionFormat': 1}
# 3                                                                  {'NoPredictionInOutput': 1}
# 4                                        {'NoPredictionInOutput': 12, 'NoPredictionFormat': 2}
# 5                                                                  {'NoPredictionInOutput': 6}
# 6                                        {'NoPredictionInOutput': 19, 'NoPredictionFormat': 2}
# 7                                         {'NoPredictionInOutput': 7, 'NoPredictionFormat': 1}
# 8                                                                  {'NoPredictionInOutput': 1}
# 9                            {'NoPredictionInOutput': 5, 'MultiplePredictionErrorInOutput': 1}
# 10                                                                 {'NoPredictionInOutput': 3}
#
#              IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0  \
# 0   {'NoPredictionInOutput': 10, 'NoPredictionFormat': 4, 'MultiplePredictionErrorInOutput': 1}
# 1                                                                  {'NoPredictionInOutput': 10}
# 2    {'NoPredictionInOutput': 8, 'MultiplePredictionErrorInOutput': 4, 'NoPredictionFormat': 3}
# 3                                          {'NoPredictionFormat': 5, 'NoPredictionInOutput': 3}
# 4                                        {'NoPredictionInOutput': 15, 'NoPredictionFormat': 14}
# 5                                          {'NoPredictionFormat': 6, 'NoPredictionInOutput': 2}
# 6                                         {'NoPredictionInOutput': 26, 'NoPredictionFormat': 5}
# 7                                          {'NoPredictionFormat': 3, 'NoPredictionInOutput': 2}
# 8                                          {'NoPredictionInOutput': 9, 'NoPredictionFormat': 2}
# 9                                          {'NoPredictionInOutput': 5, 'NoPredictionFormat': 2}
# 10                                                                    {'NoPredictionFormat': 2}
#
#                  IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0
# 0                            {'NoPredictionInOutput': 12, 'MultiplePredictionErrorInFormatting': 1}
# 1                                                                      {'NoPredictionInOutput': 10}
# 2                                 {'NoPredictionInOutput': 9, 'MultiplePredictionErrorInOutput': 9}
# 3                                                                       {'NoPredictionInOutput': 1}
# 4   {'NoPredictionInOutput': 10, 'NoPredictionFormat': 8, 'MultiplePredictionErrorInFormatting': 1}
# 5                            {'NoPredictionInOutput': 10, 'MultiplePredictionErrorInFormatting': 1}
# 6                                             {'NoPredictionInOutput': 15, 'NoPredictionFormat': 5}
# 7                                                                       {'NoPredictionInOutput': 3}
# 8                                              {'NoPredictionInOutput': 5, 'NoPredictionFormat': 1}
# 9                                                                      {'NoPredictionInOutput': 31}
# 10                                                                      {'NoPredictionInOutput': 3}

# %%
error = combined.loc[combined['prediction'] == 'NoPredictionInOutput'].sample(n=2)
for index, row in error.iterrows():
    print(row['response'])
# Out:
#  Based on the content of the document provided, I would classify it as a 'Rapportage derde kwartaal 2022 programa gebruiksmelding Oostlijn'.
#
# Here is the output in JSON format:
#
# {
# "categorie": "Rapportage derde kwartaal 2022 programa gebruiksmelding Oostlijn"
# }
#  Based on the information provided, I would classify the document as follows:
#
# {'categorie': 'Gemeenteblad'}
#
# Explanation:
#
# The document is labeled as "Gemeenteblad" which means it is a municipal bulletin or newsletter. Therefore, the category for this document is "Gemeenteblad".

# %% [markdown]
# Errors: 200 has the most errors, but similar to 100. 100/100 has the least errors. Most errors are NoPredictinInOutput, meaning that the response did include a JSON, but not a class that was in the class list.Most likely the JSON contains made-up classes, as seen in the examples.

# %%
mistakes(combined, False)
# Out:
# MISTAKES. INCLUDES PREDICTIONS ERRORS.
# Total amount of mistakes per run:
#                                                                                  run_id  \
# 0    IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0
# 1  IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0
# 2    IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0
#
#    count percentage of total predictions
# 0    635                           57.7%
# 1    632                           57.5%
# 2    578                           52.5%
# Amount of mistakes per class for each run:
#                                                                                       voordracht  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          13
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             4
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            17
#
#                                                                                       besluit  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0       37
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0         36
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0         37
#
#                                                                                       schriftelijke vraag  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                   49
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                     14
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                     48
#
#                                                                                       brief  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     92
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       98
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       99
#
#                                                                                       raadsadres  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0          87
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0            86
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0            78
#
#                                                                                       onderzoeksrapport  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0                 95
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0                   95
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0                   97
#
#                                                                                       raadsnotulen  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0             4
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0              11
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0               8
#
#                                                                                       agenda  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0      35
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0        22
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0        23
#
#                                                                                       motie  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0     46
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0       34
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0       45
#
#                                                                                       actualiteit  \
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0           91
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0             87
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0             92
#
#                                                                                       factsheet
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0         83
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0           91
# IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0           91
# Highest mistakes per class for each run:
#                     IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_100traintest_numEx0  \
# voordracht                                                                         besluit (4 out of 13)
# besluit                                                                        voordracht (21 out of 37)
# schriftelijke vraag                                                               besluit (28 out of 49)
# brief                                                                             besluit (51 out of 92)
# raadsadres                                                                        besluit (40 out of 87)
# onderzoeksrapport                                                                 besluit (43 out of 95)
# raadsnotulen                                                                     voordracht (2 out of 4)
# agenda                                                               NoPredictionInOutput (13 out of 35)
# motie                                                                             besluit (22 out of 46)
# actualiteit                                                                        agenda (25 out of 91)
# factsheet                                                                         besluit (45 out of 83)
#
#                     IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens200_0traintest_numEx0  \
# voordracht                                                             NoPredictionFormat (2 out of 4)
# besluit                                                                      voordracht (21 out of 36)
# schriftelijke vraag                                                              besluit (6 out of 14)
# brief                                                                           besluit (53 out of 98)
# raadsadres                                                                      besluit (50 out of 86)
# onderzoeksrapport                                                               besluit (32 out of 95)
# raadsnotulen                                                        NoPredictionInOutput (9 out of 11)
# agenda                                                             NoPredictionInOutput (10 out of 22)
# motie                                                                           besluit (19 out of 34)
# actualiteit                                                                      agenda (29 out of 87)
# factsheet                                                                       besluit (33 out of 91)
#
#                     IC_Llama-2-7b-chat-hfzeroshot_prompt_mistral_llamaLlamaTokens100_0traintest_numEx0
# voordracht                                                                       besluit (7 out of 17)
# besluit                                                                      voordracht (19 out of 37)
# schriftelijke vraag                                                NoPredictionInOutput (31 out of 48)
# brief                                                                      raadsnotulen (44 out of 99)
# raadsadres                                                                      besluit (49 out of 78)
# onderzoeksrapport                                                               besluit (38 out of 97)
# raadsnotulen                                                         NoPredictionInOutput (5 out of 8)
# agenda                                                             NoPredictionInOutput (10 out of 23)
# motie                                                                           besluit (15 out of 45)
# actualiteit                                                                      agenda (29 out of 92)
# factsheet                                                                       besluit (35 out of 91)

# %% [markdown]
# Mistakes: amount of mistakes is quite high for all runs (58/53%). Onderzoeksrapport, raadadres, brief, actualiteit and factsheet have many mistakes (90-ish).
